# %% [markdown]
# ## https://www.dataquest.io/blog/sql-basics/
#
# ### Covering
#  - SELECT
#  - WHERE
#  - GROUP BY
#  - JOIN
#  - Conditionals
#  - Create DB & Table
#  - INSERT, UPDATE, DELETE

# %%
import os
os.getcwd()
# os.chdir("/Users/stevewatkins/python3/demos/sqlite") # relative path: scripts dir is under Users/stevewatkins
# Out:
# 'C:\\Users\\stevewatkins\\AnacondaProjects'

# %% [markdown]
# ## create conn. and "read results" pd function

# %%
import sqlite3
import pandas as pd

db = sqlite3.connect("hubway.db")

def run_query(query):
    return pd.read_sql_query(query,db)

# %% [markdown]
# ## read metadata about sqlite DB tables

# %%
query = """
SELECT * 
FROM sqlite_master
ORDER BY name;
"""
run_query(query)
# Out:
#     type      name  tbl_name  rootpage  \
# 0  table   MyTable   MyTable     33344
# 1  table  stations  stations     33340
# 2  table     trips     trips         2
#
#                                                  sql
# 0                  CREATE TABLE MyTable(rid integer)
# 1  CREATE TABLE stations (id INTEGER, station TEX...
# 2  CREATE TABLE trips (id INTEGER, duration INTEG...

# %% [markdown]
# ## select all from table

# %%
query = "SELECT * FROM trips LIMIT 5;"
run_query(query)
# Out:
#    id  duration           start_date  start_station             end_date  \
# 0   1         9  2011-07-28 10:12:00             23  2011-07-28 10:12:00
# 1   2       220  2011-07-28 10:21:00             23  2011-07-28 10:25:00
# 2   3        56  2011-07-28 10:33:00             23  2011-07-28 10:34:00
# 3   4        64  2011-07-28 10:35:00             23  2011-07-28 10:36:00
# 4   5        12  2011-07-28 10:37:00             23  2011-07-28 10:37:00
#
#    end_station bike_number    sub_type zip_code  birth_date  gender
# 0           23      B00468  Registered   '97217      1976.0    Male
# 1           23      B00554  Registered   '02215      1966.0    Male
# 2           23      B00456  Registered   '02108      1943.0    Male
# 3           23      B00554  Registered   '02116      1981.0  Female
# 4           23      B00554  Registered   '97214      1983.0  Female

# %% [markdown]
# ## select 2 columns from table with custom order

# %%
query = """
SELECT 
     duration
    ,start_date 
FROM trips 
ORDER BY duration DESC ,start_date ASC
LIMIT 5;
"""
run_query(query)
# Out:
#    duration           start_date
# 0      9999  2012-09-26 18:34:00
# 1      9998  2011-08-09 10:42:00
# 2      9998  2012-08-15 12:11:00
# 3      9997  2011-10-09 02:30:00
# 4      9996  2011-11-19 13:48:00

# %% [markdown]
# ## select all where duration is max, using limit & order desc

# %%
query = '''
SELECT duration ,*
FROM trips
ORDER BY duration DESC
LIMIT 1;
'''

run_query(query)
# Out:
#    duration      id  duration           start_date  start_station  \
# 0      9999  541247      9999  2012-09-26 18:34:00             54
#
#               end_date  end_station bike_number sub_type zip_code birth_date  \
# 0  2012-09-26 21:21:00           54      T01078   Casual
#
#   gender
# 0

# %% [markdown]
# ## select max duration per each start_station, using group by

# %%
query = """
SELECT max(duration) ,avg(duration),start_station 
FROM trips
group by start_station
order by 1 desc
limit 5;

"""

run_query(query)
# Out:
#    max(duration)  avg(duration)  start_station
# 0           9999    1051.836841             54
# 1           9998     866.412956             40
# 2           9997    1326.620569             60
# 3           9996     801.142841              4
# 4           9996     770.682636             35

# %% [markdown]
# ## where clause to filter resultset

# %%
query = '''
SELECT * 
FROM trips
WHERE duration > 9990
--limit 5
;
'''

run_query(query)
# Out:
#         id  duration           start_date  start_station             end_date  \
# 0     4768      9994  2011-08-03 17:16:00             22  2011-08-03 20:03:00
# 1     8448      9991  2011-08-06 13:02:00             52  2011-08-06 15:48:00
# 2    11341      9998  2011-08-09 10:42:00             40  2011-08-09 13:29:00
# 3    24455      9995  2011-08-20 12:20:00             52  2011-08-20 15:07:00
# 4    55771      9994  2011-09-14 15:44:00             40  2011-09-14 18:30:00
# 5    81191      9993  2011-10-03 11:30:00             22  2011-10-03 14:16:00
# 6    89335      9997  2011-10-09 02:30:00             60  2011-10-09 05:17:00
# 7   124500      9992  2011-11-09 09:08:00             22  2011-11-09 11:55:00
# 8   133967      9996  2011-11-19 13:48:00              4  2011-11-19 16:35:00
# 9   147451      9996  2012-03-23 14:48:00             35  2012-03-23 17:35:00
# 10  315737      9995  2012-07-03 18:28:00             12  2012-07-03 21:15:00
# 11  319597      9994  2012-07-05 11:49:00             52  2012-07-05 14:35:00
# 12  416523      9998  2012-08-15 12:11:00             54  2012-08-15 14:58:00
# 13  541247      9999  2012-09-26 18:34:00             54  2012-09-26 21:21:00
#
#     end_station bike_number    sub_type zip_code birth_date gender
# 0            24      B00002      Casual
# 1            24      B00174      Casual
# 2            42      B00513      Casual
# 3            17      B00552      Casual
# 4            40      B00139      Casual
# 5            36      B00474      Casual
# 6            45      B00047      Casual
# 7            40      B00387      Casual
# 8            58      B00238      Casual
# 9            33      B00550      Casual
# 10           12      B00250  Registered   '02120       1964   Male
# 11           55      B00237      Casual
# 12           80      B00188      Casual
# 13           54      T01078      Casual

# %% [markdown]
# # AND condition

# %%
query = '''
SELECT * 
FROM trips
WHERE (duration >= 9990) AND (sub_type = "Registered")
ORDER BY duration DESC;
'''

run_query(query)
# Out:
#        id  duration           start_date  start_station             end_date  \
# 0  315737      9995  2012-07-03 18:28:00             12  2012-07-03 21:15:00
#
#    end_station bike_number    sub_type zip_code  birth_date gender
# 0           12      B00250  Registered   '02120      1964.0   Male

# %% [markdown]
# # Count with AND condition

# %%
query = '''
SELECT 
  COUNT(*) AS "Total Trips by Registered Users"  
FROM trips
WHERE sub_type = "Registered";
'''

run_query(query)
# Out:
#    Total Trips by Registered Users
# 0                          1105192

# %% [markdown]
# # Aggregating data with GROUP BY

# %%
query = '''
SELECT 
   sub_type
  ,COUNT(*) AS "Total Trips by Registered Users"  
FROM trips
group by sub_type
order by 2 desc;
'''

run_query(query)
# Out:
#      sub_type  Total Trips by Registered Users
# 0  Registered                          1105192
# 1      Casual                           464809

# %%
query = '''
SELECT sub_type, AVG(duration) AS "Average Duration"
FROM trips
GROUP BY sub_type;
'''

run_query(query)
# Out:
#      sub_type  Average Duration
# 0      Casual       1519.643897
# 1  Registered        657.026067

# %% [markdown]
# # which bike was used for the most trips?

# %%
query = '''
SELECT bike_number as "Bike Number", COUNT(*) AS "Number of Trips"
FROM trips
GROUP BY bike_number
ORDER BY COUNT(*) DESC
LIMIT 1;
'''

run_query(query)
# Out:
#   Bike Number  Number of Trips
# 0      B00490             2120

# %% [markdown]
# # Arithmetic Operators

# %%
query = '''
SELECT AVG(duration)
FROM trips
WHERE (2018 - birth_date) > 30;
'''

run_query(query)
# Out:
#    AVG(duration)
# 0     920.445299

# %%
query = '''
SELECT 
 birth_date  as "birth year"
,(2017 - birth_date) as "Years Old"
,date('now') as "now date"
,(strftime('%Y',date('now'))) as "now Year string"
,((strftime('%Y',date('now'))) - birth_date) as "Years Old revised"
FROM trips
WHERE (2018 - birth_date) > 30
and birth_date <> '';
'''

run_query(query)
# Out:
#         birth year  Years Old    now date now Year string  Years Old revised
# 0           1976.0       41.0  2018-09-24            2018               42.0
# 1           1966.0       51.0  2018-09-24            2018               52.0
# 2           1943.0       74.0  2018-09-24            2018               75.0
# 3           1981.0       36.0  2018-09-24            2018               37.0
# 4           1983.0       34.0  2018-09-24            2018               35.0
# 5           1951.0       66.0  2018-09-24            2018               67.0
# 6           1971.0       46.0  2018-09-24            2018               47.0
# 7           1971.0       46.0  2018-09-24            2018               47.0
# 8           1983.0       34.0  2018-09-24            2018               35.0
# 9           1956.0       61.0  2018-09-24            2018               62.0
# 10          1959.0       58.0  2018-09-24            2018               59.0
# 11          1982.0       35.0  2018-09-24            2018               36.0
# 12          1944.0       73.0  2018-09-24            2018               74.0
# 13          1960.0       57.0  2018-09-24            2018               58.0
# 14          1975.0       42.0  2018-09-24            2018               43.0
# 15          1956.0       61.0  2018-09-24            2018               62.0
# 16          1987.0       30.0  2018-09-24            2018               31.0
# 17          1985.0       32.0  2018-09-24            2018               33.0
# 18          1978.0       39.0  2018-09-24            2018               40.0
# 19          1971.0       46.0  2018-09-24            2018               47.0
# 20          1980.0       37.0  2018-09-24            2018               38.0
# 21          1955.0       62.0  2018-09-24            2018               63.0
# 22          1971.0       46.0  2018-09-24            2018               47.0
# 23          1943.0       74.0  2018-09-24            2018               75.0
# 24          1972.0       45.0  2018-09-24            2018               46.0
# 25          1949.0       68.0  2018-09-24            2018               69.0
# 26          1968.0       49.0  2018-09-24            2018               50.0
# 27          1967.0       50.0  2018-09-24            2018               51.0
# 28          1975.0       42.0  2018-09-24            2018               43.0
# 29          1982.0       35.0  2018-09-24            2018               36.0
# ...            ...        ...         ...             ...                ...
# 306181      1976.0       41.0  2018-09-24            2018               42.0
# 306182      1973.0       44.0  2018-09-24            2018               45.0
# 306183      1979.0       38.0  2018-09-24            2018               39.0
# 306184      1987.0       30.0  2018-09-24            2018               31.0
# 306185      1985.0       32.0  2018-09-24            2018               33.0
# 306186      1980.0       37.0  2018-09-24            2018               38.0
# 306187      1978.0       39.0  2018-09-24            2018               40.0
# 306188      1967.0       50.0  2018-09-24            2018               51.0
# 306189      1979.0       38.0  2018-09-24            2018               39.0
# 306190      1985.0       32.0  2018-09-24            2018               33.0
# 306191      1976.0       41.0  2018-09-24            2018               42.0
# 306192      1987.0       30.0  2018-09-24            2018               31.0
# 306193      1982.0       35.0  2018-09-24            2018               36.0
# 306194      1982.0       35.0  2018-09-24            2018               36.0
# 306195      1980.0       37.0  2018-09-24            2018               38.0
# 306196      1982.0       35.0  2018-09-24            2018               36.0
# 306197      1985.0       32.0  2018-09-24            2018               33.0
# 306198      1984.0       33.0  2018-09-24            2018               34.0
# 306199      1963.0       54.0  2018-09-24            2018               55.0
# 306200      1978.0       39.0  2018-09-24            2018               40.0
# 306201      1970.0       47.0  2018-09-24            2018               48.0
# 306202      1981.0       36.0  2018-09-24            2018               37.0
# 306203      1983.0       34.0  2018-09-24            2018               35.0
# 306204      1984.0       33.0  2018-09-24            2018               34.0
# 306205      1986.0       31.0  2018-09-24            2018               32.0
# 306206      1987.0       30.0  2018-09-24            2018               31.0
# 306207      1985.0       32.0  2018-09-24            2018               33.0
# 306208      1976.0       41.0  2018-09-24            2018               42.0
# 306209      1987.0       30.0  2018-09-24            2018               31.0
# 306210      1985.0       32.0  2018-09-24            2018               33.0
#
# [306211 rows x 5 columns]

# %% [markdown]
# # Joins

# %%
query = '''
SELECT *
FROM stations
where id = 23
LIMIT 5;
'''
run_query(query)
# Out:
#    id                                     station municipality  \
# 0  23  Mayor Thomas M. Menino - Government Center       Boston
#
#                   lat         lng
# 0  42.359677000000005  -71.059364

# %%
query = '''
SELECT *
FROM trips
where start_station = 23 -- or end_station = 23
LIMIT 5;
'''
run_query(query)
# Out:
#    id  duration           start_date  start_station             end_date  \
# 0   1         9  2011-07-28 10:12:00             23  2011-07-28 10:12:00
# 1   2       220  2011-07-28 10:21:00             23  2011-07-28 10:25:00
# 2   3        56  2011-07-28 10:33:00             23  2011-07-28 10:34:00
# 3   4        64  2011-07-28 10:35:00             23  2011-07-28 10:36:00
# 4   5        12  2011-07-28 10:37:00             23  2011-07-28 10:37:00
#
#    end_station bike_number    sub_type zip_code  birth_date  gender
# 0           23      B00468  Registered   '97217      1976.0    Male
# 1           23      B00554  Registered   '02215      1966.0    Male
# 2           23      B00456  Registered   '02108      1943.0    Male
# 3           23      B00554  Registered   '02116      1981.0  Female
# 4           23      B00554  Registered   '97214      1983.0  Female

# %%
query = '''
SELECT s.* ,s1.station as "end station name" ,t.*
FROM trips t
INNER JOIN stations s ON t.start_station = s.id
INNER JOIN stations s1 ON t.end_station = s1.id

and s.id = 23
--GROUP BY s.station
ORDER BY 1 DESC
--LIMIT 5;
'''

run_query(query)
# Out:
#        id                                     station municipality  \
# 0      23  Mayor Thomas M. Menino - Government Center       Boston
# 1      23  Mayor Thomas M. Menino - Government Center       Boston
# 2      23  Mayor Thomas M. Menino - Government Center       Boston
# 3      23  Mayor Thomas M. Menino - Government Center       Boston
# 4      23  Mayor Thomas M. Menino - Government Center       Boston
# 5      23  Mayor Thomas M. Menino - Government Center       Boston
# 6      23  Mayor Thomas M. Menino - Government Center       Boston
# 7      23  Mayor Thomas M. Menino - Government Center       Boston
# 8      23  Mayor Thomas M. Menino - Government Center       Boston
# 9      23  Mayor Thomas M. Menino - Government Center       Boston
# 10     23  Mayor Thomas M. Menino - Government Center       Boston
# 11     23  Mayor Thomas M. Menino - Government Center       Boston
# 12     23  Mayor Thomas M. Menino - Government Center       Boston
# 13     23  Mayor Thomas M. Menino - Government Center       Boston
# 14     23  Mayor Thomas M. Menino - Government Center       Boston
# 15     23  Mayor Thomas M. Menino - Government Center       Boston
# 16     23  Mayor Thomas M. Menino - Government Center       Boston
# 17     23  Mayor Thomas M. Menino - Government Center       Boston
# 18     23  Mayor Thomas M. Menino - Government Center       Boston
# 20     42.359677000000005  -71.059364
# 21     42.359677000000005  -71.059364
# 22     42.359677000000005  -71.059364
# 23     42.359677000000005  -71.059364
# 24     42.359677000000005  -71.059364
# 25     42.359677000000005  -71.059364
# 26     42.359677000000005  -71.059364
# 27     42.359677000000005  -71.059364
# 28     42.359677000000005  -71.059364
# 29     42.359677000000005  -71.059364
# ...                   ...         ...
# 10852  42.359677000000005  -71.059364
# 10853  42.359677000000005  -71.059364
# 10854  42.359677000000005  -71.059364
# 10855  42.359677000000005  -71.059364
# 10856  42.359677000000005  -71.059364
# 10857  42.359677000000005  -71.059364
# 10858  42.359677000000005  -71.059364
# 10859  42.359677000000005  -71.059364
# 10860  42.359677000000005  -71.059364
# 10861  42.359677000000005  -71.059364
# 10862  42.359677000000005  -71.059364
# 10863  42.359677000000005  -71.059364
# 10864  42.359677000000005  -71.059364
# 10865  42.359677000000005  -71.059364
# 10866  42.359677000000005  -71.059364
# 10867  42.359677000000005  -71.059364
# 10868  42.359677000000005  -71.059364
# 10869  42.359677000000005  -71.059364
# 10870  42.359677000000005  -71.059364
# 10871  42.359677000000005  -71.059364
# 10872  42.359677000000005  -71.059364
# 10873  42.359677000000005  -71.059364
# 10874  42.359677000000005  -71.059364
# 10875  42.359677000000005  -71.059364
# 10876  42.359677000000005  -71.059364
# 10877  42.359677000000005  -71.059364
# 10878  42.359677000000005  -71.059364
# 10879  42.359677000000005  -71.059364
# 10880  42.359677000000005  -71.059364
# 10881  42.359677000000005  -71.059364
#
#                                         end station name      id  duration  \
# 0             Mayor Thomas M. Menino - Government Center       1         9
# 1             Mayor Thomas M. Menino - Government Center       2       220
# 2             Mayor Thomas M. Menino - Government Center       3        56
# 3             Mayor Thomas M. Menino - Government Center       4        64
# 4             Mayor Thomas M. Menino - Government Center       5        12
# 5             Mayor Thomas M. Menino - Government Center       6        19
# 6             Mayor Thomas M. Menino - Government Center       7        24
# 7             Mayor Thomas M. Menino - Government Center       8         7
# 8             Mayor Thomas M. Menino - Government Center       9         8
# 9             Mayor Thomas M. Menino - Government Center      64        15
# 10                               TD Garden - Legends Way      65      2656
# 11            Mayor Thomas M. Menino - Government Center      88         4
# 12                 Faneuil Hall - Union St. at North St.     100       389
# 13                 Faneuil Hall - Union St. at North St.     101       397
# 14            Mayor Thomas M. Menino - Government Center     104       650
# 15                                         Seaport Hotel     115      2920
# 16                                       Landmark Centre     133      1933
# 17            Mayor Thomas M. Menino - Government Center     137      3373
# 18                              Cambridge St. at Joy St.     153       211
# 19            Mayor Thomas M. Menino - Government Center     156       157
# 20                                 Kenmore Sq / Comm Ave     195      1299
# 21        Seaport Square - Seaport Blvd. at Boston Wharf     221       713
# 22                              Tremont St / W Newton St     222       900
# 23                                 Summer St. / Arch St.     253       569
# 24            Mayor Thomas M. Menino - Government Center     254       970
# 25                             Stuart St. at Charles St.     279       731
# 26            Mayor Thomas M. Menino - Government Center     305      1615
# 27            Mayor Thomas M. Menino - Government Center     307      1603
# 28              Boston Public Library - 700 Boylston St.     308       769
# 29              Boston Public Library - 700 Boylston St.     310       726
# ...                                                  ...     ...       ...
# 10852                      Boylston St. at Arlington St.  546848       996
# 13         B00468  Registered   '02143       1986  Female
# 14         B00111      Casual
# 15         B00454  Registered   '02151       1987  Female
# 16         B00456      Casual
# 17         B00556      Casual
# 18         B00111  Registered   '02114       1966    Male
# 19         B00546  Registered   '02130       1982  Female
# 20         B00469  Registered   '02446       1971    Male
# 21         B00375      Casual
# 22         B00407  Registered   '02118       1978  Female
# 23         B00556      Casual
# 24         B00546      Casual
# 25         B00232  Registered   '02155       1971    Male
# 26         B00340  Registered   '02114       1986    Male
# 27         B00557  Registered   '02114       1986  Female
# 28         B00150      Casual
# 29         B00546      Casual
# ...           ...         ...      ...        ...     ...
# 10852      T01399  Registered   '02108       1963    Male
# 10853      B00028  Registered   '02109       1983    Male
# 10854      B00029      Casual
# 10855      T01211      Casual
# 10856      T01217      Casual
# 10857      T01193      Casual
# 10858      B00590  Registered   '02128       1977    Male
# 10859      B00326  Registered   '02144       1981    Male
# 10860      B00413  Registered   '02134       1985    Male
# 10861      B00528  Registered   '02215       1988    Male
# 10862      T01150  Registered   '02113       1989    Male
# 10863      T01101  Registered   '02215       1984    Male
# 10864      B00228      Casual
# 10865      B00614      Casual
# 10866      B00104      Casual
# 10867      B00572      Casual
# 10868      B00288      Casual
# 10869      B00188      Casual
# 10870      B00252  Registered   '02116       1984  Female
# 10871      B00206  Registered   '02116       1984    Male
# 10872      B00422      Casual
# 10873      B00244      Casual
# 10874      B00567      Casual
# 10875      B00538  Registered   '02108       1963    Male
# 10876      B00404      Casual
# 10877      B00541      Casual
# 10878      T01098  Registered   '02109       1988    Male
# 10879      T01102  Registered   '02141       1985    Male
# 10880      B00404  Registered   '02129       1985  Female
# 10881      B00249  Registered   '02113       1987    Male
#
# [10882 rows x 17 columns]

# %% [markdown]
# # Create new DB & table

# %%
#intentional failure; SQL is syntactically correct
query = '''
CREATE TABLE IF NOT EXISTS MyTable(rid integer);
'''

#run_query(query)

# %%
create_table_sql = '''
CREATE TABLE IF NOT EXISTS MyTable(rid integer);
'''

cn2 = sqlite3.connect("MySqlite.DB")

c = cn2.cursor()

c.execute(create_table_sql)

MyQuery = """
SELECT * 
FROM sqlite_master
ORDER BY name;
"""

c.execute(MyQuery)

c.close()

pd.read_sql_query(MyQuery,cn2)
# Out:
#     type     name tbl_name  rootpage                                sql
# 0  table  MyTable  MyTable         2  CREATE TABLE MyTable(rid integer)

# %% [markdown]
# # INSERT, UPDATE, DELETE

# %%
MyInsert = 'insert into MyTable values(-199) ,(17);'

c = cn2.cursor()

c.execute(MyInsert)

cn2.commit()

c.close()

pd.read_sql_query("select * from MyTable;",cn2)
# Out:
#    rid
# 0   17
# 1   17
# 2   17
# 3 -199
# 4   17

# %%
MyUpdate = 'update MyTable set rid = 0 where rid = -199;'

c = cn2.cursor()

c.execute(MyUpdate)

cn2.commit()

c.close()

pd.read_sql_query("select * from MyTable;",cn2)
# Out:
#    rid
# 0   17
# 1   17
# 2   17
# 3    0
# 4   17

# %%
MyDelete = 'delete from MyTable where rid = 0;'

c = cn2.cursor()

c.execute(MyDelete)

cn2.commit()

c.close()

pd.read_sql_query("select * from MyTable;",cn2)
# Out:
#    rid
# 0   17
# 1   17
# 2   17
# 3   17
